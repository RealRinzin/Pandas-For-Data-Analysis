# %%
# !pip3 install pandas

# %% [markdown]
# #### Read CSV File from Internet

# %%
import pandas as pd
# read_csv_file = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data',verify_ssl=False)
read_csv_file = pd.read_csv('./crime_data.csv')
read_csv_file.head(6)
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.60  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front   88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front   94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front   99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front   99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front   99.8  ...
# 5  1  158         audi  gas  std  four        sedan  fwd  front  105.8  ...
#
#    130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
# 5  136  mpfi  3.19  3.40   8.5  110  5500  19  25  17710
#
# [6 rows x 26 columns]

# %% [markdown]
# #### Exporting the data to CSV Format

# %%
# List of list
list = [[1,"Rahul","M","A+"],[2,"Tenzin","M","A"]]

# Converting it to DataFrame
df = pd.DataFrame(list,columns=['ID','name','gender','grade'])

# Exporting it to the CSV format
df.to_csv('exported_to_format.csv')
# Out:
#    ID    name gender grade
# 0   1   Rahul      M    A+
# 1   2  Tenzin      M     A

# %% [markdown]
# #### Describe method to overview the statistical values of the table

# %%
# Describe usually return the min,max,count,avg of all the numerical columns
# but if you want it for all the columns then you have to 
# pass include='all' parameter in describe function
read_csv_file.describe()
# Out:
#                 3       88.60      168.80       64.10       48.80  \
# count  204.000000  204.000000  204.000000  204.000000  204.000000
# mean     0.823529   98.806373  174.075000   65.916667   53.749020
# std      1.239035    5.994144   12.362123    2.146716    2.424901
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.075000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.200000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#               2548         130        9.00          21          27
# count   204.000000  204.000000  204.000000  204.000000  204.000000
# mean   2555.602941  126.892157   10.148137   25.240196   30.769608
# std     521.960820   41.744569    3.981000    6.551513    6.898337
# min    1488.000000   61.000000    7.000000   13.000000   16.000000
# ...

# %%
# with include='all' parameter | usually it does not make lots of sense to call non-numerical columns for statistical overview
read_csv_file.describe(include='all')
# Out:
#                  3    ? alfa-romero  gas  std   two convertible  rwd  front  \
# count   204.000000  204         204  204  204   204         204  204    204
# unique         NaN   52          22    2    2     3           5    3      2
# top            NaN    ?      toyota  gas  std  four       sedan  fwd  front
# freq           NaN   40          32  184  167   114          96  120    201
# mean      0.823529  NaN         NaN  NaN  NaN   NaN         NaN  NaN    NaN
# std       1.239035  NaN         NaN  NaN  NaN   NaN         NaN  NaN    NaN
# min      -2.000000  NaN         NaN  NaN  NaN   NaN         NaN  NaN    NaN
# 25%       0.000000  NaN         NaN  NaN  NaN   NaN         NaN  NaN    NaN
# 50%       1.000000  NaN         NaN  NaN  NaN   NaN         NaN  NaN    NaN
# 75%       2.000000  NaN         NaN  NaN  NaN   NaN         NaN  NaN    NaN
# max       3.000000  NaN         NaN  NaN  NaN   NaN         NaN  NaN    NaN
#
# ...

# %% [markdown]
# ### Analysis the information / structure of the table

# %%
# View the information of the table
read_csv_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   3            204 non-null    int64
#  1   ?            204 non-null    object
#  2   alfa-romero  204 non-null    object
#  3   gas          204 non-null    object
#  4   std          204 non-null    object
#  5   two          204 non-null    object
#  6   convertible  204 non-null    object
#  7   rwd          204 non-null    object
#  8   front        204 non-null    object
#  9   88.60        204 non-null    float64
#  10  168.80       204 non-null    float64
#  11  64.10        204 non-null    float64
#  12  48.80        204 non-null    float64
#  13  2548         204 non-null    int64
#  14  dohc         204 non-null    object
#  15  four         204 non-null    object
#  16  130          204 non-null    int64
#  17  mpfi         204 non-null    object
# ...
